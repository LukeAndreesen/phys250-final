# %%
from qiskit.quantum_info import SparsePauliOp
from qiskit.circuit.library import QAOAAnsatz
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import Session, EstimatorV2 as Estimator
from qiskit_ibm_runtime import SamplerV2 as Sampler
from qbraid.runtime.qiskit import QiskitRuntimeProvider

from scipy.optimize import minimize
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
from dotenv import load_dotenv
import os

# %%
# !pip install pip install qbraid-qir
# Out:
# Requirement already satisfied: pip in /opt/homebrew/lib/python3.11/site-packages (24.3.1)
# Requirement already satisfied: install in /Users/lukeandreesen/Library/Python/3.11/lib/python/site-packages (1.3.5)
# Requirement already satisfied: qbraid-qir in /opt/homebrew/lib/python3.11/site-packages (0.2.3)
# Requirement already satisfied: pyqir<0.11.0,>=0.10.0 in /opt/homebrew/lib/python3.11/site-packages (from qbraid-qir) (0.10.6)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from qbraid-qir) (1.26.4)

# %%
#mode="simulate"
#mode="real"
mode = "qbraid"

# %% [markdown]
# NOTE: THE STATE |0> corresponds to z=+1; the state |1> corresponds to z=-1

# %%
load_dotenv()
ibm_token = os.getenv('IBM_TOKEN')
print(ibm_token)
providor = QiskitRuntimeProvider(ibm_token)
# Out:
# 831dd959d21e9151bce0ce49b0b2058f24e6fe738ea71e01b06020085fcb03ff135be2a7616d68ef25215ff34817e66101740136b9efbb81a1f7180446a0549b

# %%
device = providor.get_devices()[0]

# %%
device
# Out:
# <qbraid.runtime.ibm.device.QiskitBackend('ibm_brisbane')>

# %%
def qubit_idx(i, j, n_cols):
    return i * n_cols + j

# %%
from qiskit.quantum_info import SparsePauliOp

def build_ising_pauli_list(J, h):
    """
    Build the Pauli list for a 2D grid Ising Hamiltonian using a numpy array and periodic boundaries.

    Args:
        J (np.ndarray): 2D numpy array of coupling constants (J values) between nearest neighbors.
        h (np.ndarray): 2D numpy array of external magnetic field strengths.

    Returns:
        SparsePauliOp: Ising Hamiltonian as a SparsePauliOp.
    """
    import numpy as np

    rows, cols = J.shape
    n_qubits = rows * cols
    pauli_list = []

    def qubit_idx(i, j, cols):
        return i * cols + j

    # Add interaction terms
    for i in range(rows):
        for j in range(cols):
            current_index = qubit_idx(i, j, cols)

            # Horizontal interaction (right neighbor)
            if j + 1 < cols:  # Include periodic boundary if required
                ni, nj = i, (j + 1) % cols
                neighbor_index = qubit_idx(ni, nj, cols)
                paulis = ["I"] * n_qubits
                paulis[current_index] = "Z"
                paulis[neighbor_index] = "Z"
                pauli_list.append(("".join(paulis), -J[i, j]))

            # Vertical interaction (bottom neighbor)
            if i + 1 < rows:  # Include periodic boundary if required
                ni, nj = (i + 1) % rows, j
                neighbor_index = qubit_idx(ni, nj, cols)
                paulis = ["I"] * n_qubits
                paulis[current_index] = "Z"
                paulis[neighbor_index] = "Z"
                pauli_list.append(("".join(paulis), -J[i, j]))

            # External field term
            paulis = ["I"] * n_qubits
            paulis[current_index] = "Z"
            pauli_list.append(("".join(paulis), -h[i, j]))

    # Convert to SparsePauliOp
    return SparsePauliOp.from_list(pauli_list)

# %%
# Define params
n_rows = 2
n_cols = 2
reps = 2

# %%
#h = 0.7  # Magnetic field
#h = np.random.rand(n_rows, n_cols)
h = np.load('h_2_2.npy') # qaoa be default has this as positive
#h=np.array([[-0.42900093,-0.34531477], [-0.1746655,-0.28350231]])

n_rows, n_cols = h.shape
J = np.full((n_rows, n_cols), 1.0)
ising_hamiltonian = build_ising_pauli_list(J, h)
h
# Out:
# array([[0.95830537, 0.5582596 ],
#        [0.70101119, 0.2148184 ]])

# %%
circuit = QAOAAnsatz(cost_operator=ising_hamiltonian, reps=reps)
circuit.measure_all()
circuit.draw('mpl')

# %%
circuit.parameters
# Out:
# ParameterView([ParameterVectorElement(β[0]), ParameterVectorElement(β[1]), ParameterVectorElement(γ[0]), ParameterVectorElement(γ[1])])

# %%
QiskitRuntimeService.save_account(channel="ibm_quantum", token=ibm_token, overwrite=True, set_as_default=True)

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram, plot_state_city
import qiskit.quantum_info as qi
simulator = AerSimulator()

# %%
#service = QiskitRuntimeService(channel='ibm_quantum')
#backend = service.least_busy(min_num_qubits=127)
if (mode == "simulate"):
    backend = simulator
if (mode == "qbraid"):
    backend = device
print(device)
# Out:
# QiskitBackend('ibm_brisbane')

# %%
#pm = generate_preset_pass_manager(optimization_level=3,backend=backend)
candidate_circuit = backend.run(circuit)
#candidate_circuit.draw('mpl', fold=False, idle_wires=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 2
#       1 #pm = generate_preset_pass_manager(optimization_level=3,backend=backend)
# ----> 2 candidate_circuit = backend.run(circuit)
#       3 #candidate_circuit.draw('mpl', fold=False, idle_wires=False)
#
# File /opt/homebrew/lib/python3.11/site-packages/qbraid/runtime/device.py:425, in QuantumDevice.run(self, run_input, *args, **kwargs)
#     423 is_single_input = not isinstance(run_input, list)
#     424 run_input = [run_input] if is_single_input else run_input
# --> 425 run_input_compat = [self.apply_runtime_profile(program) for program in run_input]
#     426 run_input_compat = run_input_compat[0] if is_single_input else run_input_compat
#     427 return self.submit(run_input_compat, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/qbraid/runtime/device.py:425, in <listcomp>(.0)
#     423 is_single_input = not isinstance(run_input, list)
#     424 run_input = [run_input] if is_single_input else run_input
# --> 425 run_input_compat = [self.apply_runtime_profile(program) for program in run_input]
#     426 run_input_compat = run_input_compat[0] if is_single_input else run_input_compat
#     427 return self.submit(run_input_compat, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/qbraid/runtime/device.py:383, in QuantumDevice.apply_runtime_profile(self, run_input)
#     381 if self._target_spec is not None and self._options.get("transpile") is True:
#     382     run_input_alias = get_program_type_alias(run_input, safe=True)
# --> 383     run_input_spec = ProgramSpec(type(run_input), alias=run_input_alias)
#     384     run_input = self.transpile(run_input, run_input_spec)
#     386 is_single_output = not isinstance(run_input, list)
#
# File /opt/homebrew/lib/python3.11/site-packages/qbraid/programs/spec.py:42, in ProgramSpec.__init__(self, program_type, alias, overwrite, to_ir, validate, experiment_type)
#      39 self._to_ir = to_ir or (lambda program: program)
#      40 self._validate = validate or (lambda program: None)
# ---> 42 register_program_type(program_type, alias=alias, overwrite=overwrite)
#      43 self._alias = alias or derive_program_type_alias(program_type)
#      44 self._native = is_registered_alias_native(self._alias)
#
# File /opt/homebrew/lib/python3.11/site-packages/qbraid/programs/registry.py:109, in register_program_type(program_type, alias, overwrite)
#     107             program_type = registered_type
#     108         else:
# --> 109             raise ValueError(f"Alias '{alias}' is already registered with a different type.")
#     111 # Check if the type is already registered under any other alias
#     112 existing_alias = next((k for k, v in QPROGRAM_REGISTRY.items() if v == program_type), None)
#
# ValueError: Alias 'qiskit' is already registered with a different type.

# %%
initial_gamma = np.pi
initial_beta = np.pi

init_params = []
for i in range(reps):
    init_params.append(initial_gamma)
    init_params.append(initial_beta)

# %%
def cost_func_estimator(params, ansatz, hamiltonian, estimator):

    # transform the observable defined on virtual qubits to
    # an observable defined on all physical qubits
    isa_hamiltonian = hamiltonian.apply_layout(ansatz.layout)

    pub = (ansatz, isa_hamiltonian, params)
    job = estimator.run([pub])

    results = job.result()[0]
    cost = results.data.evs

    objective_func_vals.append(cost)


    return cost

# %%
objective_func_vals = [] # Global variable
with Session(backend=backend) as session:
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 1000

    # Set simple error suppression/mitigation options
    estimator.options.dynamical_decoupling.enable = True
    estimator.options.dynamical_decoupling.sequence_type = "XY4"
    estimator.options.twirling.enable_gates = True
    estimator.options.twirling.num_randomizations = "auto"

    result = minimize(
        cost_func_estimator,
        init_params,
        args=(candidate_circuit, ising_hamiltonian, estimator),
        method="COBYLA",
        tol=1e-2,
    )
    print(result)
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: -1.7794330365861728
#        x: [ 4.309e+00  3.437e+00  2.937e+00  2.987e+00]
#     nfev: 30
#    maxcv: 0.0

# %%
plt.figure(figsize=(12, 6))
plt.plot(objective_func_vals)
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.show()

# %%
objective_func_vals
# Out:
# [array(0.1535335),
#  array(-0.12619149),
#  array(0.6869492),
#  array(0.61532014),
#  array(0.17828607),
#  array(-0.02999072),
#  array(0.90064886),
#  array(-0.62214918),
#  array(-0.53475737),
#  array(-0.17381178),
#  array(-0.30201918),
#  array(-1.63211431),
#  array(-1.03469544),
#  array(-1.1838347),
#  array(-1.86178652),
#  array(-1.73531159),
#  array(-2.16916024),
#  array(-1.69048237),
#  array(-1.59707096),
#  array(-1.89337968),
#  array(-1.91613218),
#  array(-1.69013645),
#  array(-1.67061651),
#  array(-1.85021432),
#  array(-1.84988193),
#  array(-1.65708003),
#  array(-1.99837878),
#  array(-1.67178893),
#  array(-1.92323738),
#  array(-1.77943304)]

# %%
optimized_circuit = candidate_circuit.assign_parameters(result.x)
optimized_circuit.draw('mpl', fold=False, idle_wires=False)

# %%
sampler = Sampler(mode=backend)
sampler.options.default_shots = 10000

# Set simple error suppression/mitigation options
sampler.options.dynamical_decoupling.enable = True
sampler.options.dynamical_decoupling.sequence_type = "XY4"
sampler.options.twirling.enable_gates = True
sampler.options.twirling.num_randomizations = "auto"

pub= (optimized_circuit, )
job = sampler.run([pub], shots=int(1e4))
counts_int = job.result()[0].data.meas.get_int_counts()
counts_bin = job.result()[0].data.meas.get_counts()
shots = sum(counts_int.values())
final_distribution_int = {key: val/shots for key, val in counts_int.items()}
final_distribution_bin = {key: val/shots for key, val in counts_bin.items()}
print(final_distribution_int)
# Out:
# {15: 0.1361, 1: 0.1477, 5: 0.1479, 0: 0.1837, 3: 0.0713, 13: 0.0618, 9: 0.0159, 7: 0.062, 8: 0.0274, 2: 0.0177, 4: 0.0253, 11: 0.0268, 12: 0.0322, 14: 0.012, 10: 0.0209, 6: 0.0113}

# %%
# auxiliary functions to sample most likely bitstring
def to_bitstring(integer, num_bits):
    result = np.binary_repr(integer, width=num_bits)
    return [int(digit) for digit in result]

keys = list(final_distribution_int.keys())
values = list(final_distribution_int.values())
most_likely = keys[np.argmax(np.abs(values))]
most_likely_bitstring = to_bitstring(most_likely, (n_rows * n_cols))
most_likely_bitstring.reverse()

print("Result bitstring:", most_likely_bitstring)
# Out:
# Result bitstring: [0, 0, 0, 0]

# %%
matplotlib.rcParams.update({"font.size": 10})
final_bits = final_distribution_bin
values = np.abs(list(final_bits.values()))
print(values)
top_4_values = sorted(values, reverse=True)[:4]
print(top_4_values)
positions = []

fig = plt.figure(figsize=(11, 6))
ax = fig.add_subplot(1, 1, 1)
plt.xticks(rotation=45)
plt.title("Result Distribution")
plt.xlabel("Bitstrings (reversed)")
plt.ylabel("Probability")
ax.bar(list(final_bits.keys()), list(final_bits.values()), color="tab:grey")
for p in positions:
    ax.get_children()[int(p)].set_color("tab:purple")
plt.show()
# Out:
# [0.1361 0.1477 0.1479 0.1837 0.0713 0.0618 0.0159 0.062  0.0274 0.0177
#  0.0253 0.0268 0.0322 0.012  0.0209 0.0113]
# [0.1837, 0.1479, 0.1477, 0.1361]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming final_bits is a dictionary of bitstrings and their probabilities
final_bits = final_distribution_bin  # Replace this with your actual data

# Get the top 10 bitstrings by probability
sorted_bits = sorted(final_bits.items(), key=lambda x: x[1], reverse=True)[:10]
top_10_keys = [k for k, _ in sorted_bits]
top_10_values = [v for _, v in sorted_bits]

# Get the indices of the top 4 probabilities
top_4_indices = sorted(range(len(top_10_values)), key=lambda i: top_10_values[i], reverse=True)[:4]

# Create the plot
fig = plt.figure(figsize=(11, 6))
ax = fig.add_subplot(1, 1, 1)

plt.xticks(rotation=45)
plt.title("Top 10 Result Distribution")
plt.xlabel("Bitstrings (reversed)")
plt.ylabel("Probability")

# Bar plot for top 10 probabilities
bars = ax.bar(top_10_keys, top_10_values, color="tab:grey")

# Highlight the top 4 bars in purple
for i in top_4_indices:
    bars[i].set_color("tab:purple")

plt.show()
